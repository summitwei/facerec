# %% [markdown]
# # Facial Recognition

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Eric: Takes all existing pictures and makes a database of the 'name:descriptor_vectors' and 'name:mean_vector' dictionaries

# %%
import make_database

make_database.add_to_dict()
# Out:
# who is this?aditya
# (720, 1280, 3)
# (720, 1280, 3)
# [rectangle(613,387,799,573)]

# %% [markdown]
# Charles: Take the full picture currently being taken, and passes it to dlib to get the cropped image and the shape.

# %%
import C

# %% [markdown]
# Varun: Now, let's import the files that will ompare this cropped image of a face to a descriptory vector, then to the database. Ultimately, it will produce a match.

# %%
import FaceToDescription

vect = FaceToDescription.face_to_vector(face, shape)
match = desc_comp_data(vect)
print(match)

# %% [markdown]
# Aditya: Stitch all the above jobs together, and display the name to updated users database (.pickle). Lastly, end the user agreement.

# %%
import endUser

endUser.main()
# Out:
# Type yes to take a picture and recognize facesyes
# (720, 1280, 3)
# (720, 1280, 3)
# [rectangle(563,242,786,464)]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-1dac92037a45> in <module>
#       1 import endUser
#       2
# ----> 3 endUser.main()
#
# ~/Documents/BWSI/PyCharm_Code/facerec/endUser.py in main()
#      38     for index,a in enumerate(detections):
#      39         desc_vector=face_to_vector(img_array,shapes[index])
# ---> 40         match=desc_comp_data(desc_vector)
#      41         l,r,t,b=a.left(),a.right(),a.top(),a.bottom()
#      42
#
# ~/Documents/BWSI/PyCharm_Code/facerec/FaceToDescription.py in desc_comp_data(vect)
#      53     closest = mydictkeys[0]
#      54     for key in diffs:
# ---> 55         if diffs[key]<least:
#      56             least = diffs[key]
#      57             closest = key
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
